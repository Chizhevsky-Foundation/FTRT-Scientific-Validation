# %% [markdown]
# # 🚀 FTRT Scientific Validation - PRUEBA
# ## Sistema operativo desde Termux Android
# ### Creado en honor a Alexander Chizhevsky

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("✓ FTRT Environment Ready!")
print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")

# Datos de prueba
data = {'Evento': ['Carrington 1859', 'Tormenta 1989'],
        'FTRT_Score': [0.85, 0.72]}
df = pd.DataFrame(data)
print(f"\n📊 Datos de prueba:\n{df}")
